# %%
import csv

def print_cap_proj():
    with open('capital_projects.csv', 'r') as projs:
        reader = csv.DictReader(projs)
        for d in reader:
            print (d)

# %%
print_cap_proj()
# Out:
# OrderedDict([('id', '1850147310'), ('name', 'BRIDGE REPAIRS'), ('task_description', 'Columbus Avenue Bridge Handicapped Ramp and Intersection Improvements'), ('area', 'Engineering and Construction'), ('budgeted_amount', '100000'), ('status', 'Planned'), ('asset_id', 'Columbus Avenue Bridge'), ('asset_type', 'Bridge'), ('fiscal_year', '2017'), ('start_date', '2017-02-08'), ('inactive', 'f'), ('neighborhood', 'Manchester'), ('council_district', '6'), ('ward', '21'), ('tract', '42003210700'), ('public_works_division', '1'), ('pli_division', '21'), ('police_zone', '1'), ('fire_zone', '1-8'), ('latitude', '40.45848456'), ('longitude', '-80.02443938')])
# ...

# %%
def fill_in_area():
    with open ('capital_projects.csv', 'r') as projs:
        reader = csv.DictReader(projs)
        for p in reader:
            if p['area'] == '':
                logMalformedproj(p)
     #   if p['area'] not in projs:

# %%
def logMalformedproj(project):
    with open ('missing_area.txt', 'a') as log:
        log.write(project['id'])
        log.write('\n')

# %%
fill_in_area()

# %%
def filter_out_proj():
    user_input = input('Please specify a search criteria: ')
    with open ('capital_projects', 'r') as projs:
        reader = csv.DictReader(projs)
        for p in reader:
            if p['start_date'] == user_input:
                filtered_results(p)

# %%
def filtered_results(project):
    with open ('filtered_results.txt', 'a') as filter:
        log.write(project['id'])
        log.write('\n')
