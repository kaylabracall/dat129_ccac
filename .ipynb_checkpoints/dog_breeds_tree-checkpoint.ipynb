# %%
from zipfile import ZipFile
import os
import re

# %%
for loc, dir, files in os.walk('.'): 
    print(loc, ' ', dir, ' ', files)
# Out:
# .   ['.git', '.ipynb_checkpoints', 'Week1', 'Week10', 'Week11', 'Week3', 'Week4', 'Week5', 'Week6', 'Week8', 'Week9']   ['.~lock.Python 2 - Running Notes.odt#', 'LICENSE', 'markdown_practice.md', 'README.md']
# .\.git   ['hooks', 'info', 'logs', 'objects', 'refs']   ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD', 'packed-refs']
# .\.git\hooks   []   ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'update.sample']
# .\.git\info   []   ['exclude']
# .\.git\logs   ['refs']   ['HEAD']
# .\.git\logs\refs   ['heads', 'remotes']   []
# .\.git\logs\refs\heads   []   ['master', 'working']
# .\.git\logs\refs\remotes   ['origin']   []
# .\.git\logs\refs\remotes\origin   []   ['HEAD', 'master']
# ...
