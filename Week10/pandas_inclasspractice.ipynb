# %%
import numpy as np
import pandas as pd

# %%
violationsdf = pd.read_csv('violations.csv')
print(type(violationsdf))
print(violationsdf.head())
print(violationsdf.dtypes)
# extract an individual column from the "table" ie the DataFrame
codeviolations = violationsdf['description_new']
# ask the column how many rows
print(codeviolations.size)
# on our Series Object, ask for a tabulation of each unqiue value and its respective counts 
print(codeviolations.value_counts())

munis = violationsdf['municipal']
print(munis.value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       encounter     id  placard_st  \
# 0  201502270009  10762           1
# 1  201502270009  10762           1
# 2  201602100042  10762           1
# 3  201602100042  10762           1
# 4  201602100042  10762           1
#
#                                        facility_name bus_st_date  \
# 0  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 1  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 2  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 3  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 4  North Versailles VFD / South Wilmerding Social...  1969-01-01
#
#             description                                    description_new  \
# 0  Social Club-Bar Only                             Handwashing Facilities
# 1  Social Club-Bar Only  Fabrication, Design, Installation and Maintenance
# 2  Social Club-Bar Only                          Employee Personal Hygiene
# 3  Social Club-Bar Only                             Handwashing Facilities
# 4  Social Club-Bar Only  Contamination Prevention - Food, Utensils and ...
#
#    num      street              city  ...      zip  inspect_dt start_time  \
# 0  830  Sylvan Ave  North Versailles  ...  15137.0  2015-02-27   10:45:00
# 1  830  Sylvan Ave  North Versailles  ...  15137.0  2015-02-27   10:45:00
# 2  830  Sylvan Ave  North Versailles  ...  15137.0  2016-02-10   14:00:00
# 3  830  Sylvan Ave  North Versailles  ...  15137.0  2016-02-10   14:00:00
# 4  830  Sylvan Ave  North Versailles  ...  15137.0  2016-02-10   14:00:00
#
#    end_time         municipal rating low medium high  \
# 0  11:30:00  North Versailles      V   T      F    F
# 1  11:30:00  North Versailles      V   T      F    F
# 2  14:50:00  North Versailles      V   F      F    T
# 3  14:50:00  North Versailles      V   T      F    F
# 4  14:50:00  North Versailles      V   T      F    F
#
#                                                  url
# 0  http://appsrv.alleghenycounty.us/reports/rwser...
# 1  http://appsrv.alleghenycounty.us/reports/rwser...
# 2  http://appsrv.alleghenycounty.us/reports/rwser...
# 3  http://appsrv.alleghenycounty.us/reports/rwser...
# 4  http://appsrv.alleghenycounty.us/reports/rwser...
#
# [5 rows x 21 columns]
# encounter            int64
# id                   int64
# placard_st           int64
# facility_name       object
# bus_st_date         object
# description         object
# description_new     object
# num                 object
# street              object
# city                object
# state               object
# zip                float64
# inspect_dt          object
# start_time          object
# end_time            object
# municipal           object
# rating              object
# low                 object
# medium              object
# high                object
# url                 object
# dtype: object
# 238859
# Cleaning and Sanitization                                  24517
# Fabrication, Design, Installation and Maintenance          20184
# Cold Holding Temperatures                                  14234
# Contamination Prevention - Food, Utensils and Equipment    13809
# Floors                                                     12775
# Handwashing Facilities                                     12603
# Facilities to Maintain Temperature                         12573
# Walls and ceilings                                         12566
# Certified Food Protection Manager                          11652
# Pest Management                                             9601
# Date Marking of Food                                        9013
# Toxic Items                                                 8029
# Garbage and Refuse                                          7328
# Cooling Food                                                7200
# Toilet Room                                                 6486
# Plumbing                                                    6292
# Cross-Contamination Prevention                              5698
# Lighting                                                    5383
# General Premises                                            5204
# Food Source/Condition                                       4858
# Administrative                                              4623
# Ventilation                                                 4535
# Probe-Type Thermometers                                     3839
# Hot Holding Temperatures                                    3787
# Waste Water Disposal                                        3053
# Employee Personal Hygiene                                   3010
# Water Supply                                                2409
# Consumer Advisory                                           1691
# Demonstration of Knowledge                                  1107
# Reheating Temperatures                                       386
# Dressing rooms and Locker rooms                              347
# Cooking Temperatures                                          48
# Employee Health                                               19
# Name: description_new, dtype: int64
# Pittsburgh-104      13019
# Pittsburgh-102      11636
# Pittsburgh-114       7995
# Ross                 7730
# Robinson             6752
#                     ...
# Glenfield              14
# Thornburg               9
# Pittsburgh (All)        8
# Osborne                 7
# Unspecified             1
# Name: municipal, Length: 160, dtype: int64

# %%
# extract individual rows from our DataFrame, based first on index value 
print(violationsdf.iloc[0:10])

# build a DataFrame containing only rows whos violation was in Robinson municipality 

# use the loc function to select only rows who when processed by the lambda function return a true value
# ask it a true false question 
robviols = violationsdf.loc[lambda violationsdf: violationsdf['municipal'].isin['Robinson']]
# extracted the column of violations as a series and asked for the tally of unique value counts 
robviols['description_new'].value_counts
# Out:
#       encounter     id  placard_st  \
# 0  201502270009  10762           1
# 1  201502270009  10762           1
# 2  201602100042  10762           1
# 3  201602100042  10762           1
# 4  201602100042  10762           1
# 5  201602100042  10762           1
# 6  201703310016  10762           1
# 7  201703310016  10762           1
# 8  201703170006  10762           1
# 9  201703170006  10762           1
#
#                                        facility_name bus_st_date  \
# 0  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 1  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 2  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 3  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 4  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 5  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 6  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 7  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 8  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 9  North Versailles VFD / South Wilmerding Social...  1969-01-01
#
#             description                                    description_new  \
# 0  Social Club-Bar Only                             Handwashing Facilities
# 1  Social Club-Bar Only  Fabrication, Design, Installation and Maintenance
# 2  Social Club-Bar Only                          Employee Personal Hygiene
# 3  Social Club-Bar Only                             Handwashing Facilities
# 4  Social Club-Bar Only  Contamination Prevention - Food, Utensils and ...
# 5  Social Club-Bar Only                                        Ventilation
# 6  Social Club-Bar Only  Fabrication, Design, Installation and Maintenance
# 7  Social Club-Bar Only                                             Floors
# 8  Social Club-Bar Only                           Hot Holding Temperatures
# 9  Social Club-Bar Only                 Facilities to Maintain Temperature
#
#    num      street              city  ...      zip  inspect_dt start_time  \
# 0  830  Sylvan Ave  North Versailles  ...  15137.0  2015-02-27   10:45:00
# 1  830  Sylvan Ave  North Versailles  ...  15137.0  2015-02-27   10:45:00
# 2  830  Sylvan Ave  North Versailles  ...  15137.0  2016-02-10   14:00:00
# 3  830  Sylvan Ave  North Versailles  ...  15137.0  2016-02-10   14:00:00
# 4  830  Sylvan Ave  North Versailles  ...  15137.0  2016-02-10   14:00:00
# 5  830  Sylvan Ave  North Versailles  ...  15137.0  2016-02-10   14:00:00
# 6  830  Sylvan Ave  North Versailles  ...  15137.0  2017-03-31   13:00:00
# 7  830  Sylvan Ave  North Versailles  ...  15137.0  2017-03-31   13:00:00
# 8  830  Sylvan Ave  North Versailles  ...  15137.0  2017-03-17   10:50:00
# 9  830  Sylvan Ave  North Versailles  ...  15137.0  2017-03-17   10:50:00
#
#    end_time         municipal rating low medium high  \
# 0  11:30:00  North Versailles      V   T      F    F
# 1  11:30:00  North Versailles      V   T      F    F
# 2  14:50:00  North Versailles      V   F      F    T
# 3  14:50:00  North Versailles      V   T      F    F
# 4  14:50:00  North Versailles      V   T      F    F
# 5  14:50:00  North Versailles      V   T    NaN  NaN
# 6  13:25:00  North Versailles      V   T      F    F
# 7  13:25:00  North Versailles      V   T    NaN  NaN
# 8  12:05:00  North Versailles      V   F      F    T
# 9  12:05:00  North Versailles      V   T      F    F
#
#                                                  url
# 0  http://appsrv.alleghenycounty.us/reports/rwser...
# 1  http://appsrv.alleghenycounty.us/reports/rwser...
# 2  http://appsrv.alleghenycounty.us/reports/rwser...
# 3  http://appsrv.alleghenycounty.us/reports/rwser...
# 4  http://appsrv.alleghenycounty.us/reports/rwser...
# 5  http://appsrv.alleghenycounty.us/reports/rwser...
# 6  http://appsrv.alleghenycounty.us/reports/rwser...
# 7  http://appsrv.alleghenycounty.us/reports/rwser...
# 8  http://appsrv.alleghenycounty.us/reports/rwser...
# 9  http://appsrv.alleghenycounty.us/reports/rwser...
#
# [10 rows x 21 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-567ad7f5a032> in <module>
#       6 # use the loc function to select only rows who when processed by the lambda function return a true value
#       7 # ask it a true false question
# ----> 8 robviols = violationsdf.loc[lambda violationsdf: violationsdf['municipal'].isin['Robinson']]
#       9 # extracted the column of violations as a series and asked for the tally of unique value counts
#      10 robviols['description_new'].value_counts
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1421             axis = self.axis or 0
#    1422
# -> 1423             maybe_callable = com.apply_if_callable(key, self.obj)
#    1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     363
#     364     if callable(maybe_callable):
# --> 365         return maybe_callable(obj, **kwargs)
#     366
#     367     return maybe_callable
#
# <ipython-input-24-567ad7f5a032> in <lambda>(violationsdf)
#       6 # use the loc function to select only rows who when processed by the lambda function return a true value
#       7 # ask it a true false question
# ----> 8 robviols = violationsdf.loc[lambda violationsdf: violationsdf['municipal'].isin['Robinson']]
#       9 # extracted the column of violations as a series and asked for the tally of unique value counts
#      10 robviols['description_new'].value_counts
#
# TypeError: 'method' object is not subscriptable
